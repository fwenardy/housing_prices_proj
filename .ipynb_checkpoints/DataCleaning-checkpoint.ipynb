# %%
import pandas as pd

# %%
def transform_price(price):
    try:
        price = price.replace(',', '.')
        
        # Step 2: Extract the numeric value and suffix
        suffix = price[-2:]  # Last two characters (e.g., "rb", "jt", "M")
        
        # Step 3: Handle suffix cases and multiply accordingly
        if suffix == 'jt':
            price_value = float(price[:-2]) * 1_000_000
        elif suffix == ' M':
            price_value = float(price[:-2]) * 1_000_000_000
        elif suffix == 'rb':
            price_value = float(price[:-2]) * 1_000
        else:
            price_value = float(price)
        return price_value
    
    except (ValueError, TypeError) as e:
        return None

# %%
def clean(data):
    data['bed'] = data['bed'].fillna(data['bed'].median())
    data['bath'] = data['bath'].fillna(data['bath'].median())
    data.area = data.area.astype(str)
    data['area'] = data['area'].str[:-3].astype(int)
    
    data['price'] = data['price'].apply(transform_price)
    data = data.dropna()
    return data

# %%
def remove_outliers(data):
    for col in ['area','price']:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
    
        #being a bit generous with 5xIQR, with the standard being 1.5x, but I'm being generous - only removing unrealistic scam/promotional postings.
        upper_bound = Q3 + 5 * IQR
        data = data[(data[col] <= upper_bound)]

    #IQR method doesn't really help with lower bounds, so I'll use judgment from what I know for the lower bounds.
    area_lower_bound = 15
    price_lower_bound = 10**7
    data = data[(data['area'] >= area_lower_bound)]
    data = data[(data['price'] >= price_lower_bound)]
    return data

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data = clean(train_data)
train_data = remove_outliers(train_data)

test_data = clean(test_data)
test_data = remove_outliers(train_data)

# %%
train_data.head()
# Out:
#                                                  url  \
# 0  https://www.rumah.com/listing-properti/dijual-...
# 1  https://www.rumah.com/listing-properti/dijual-...
# 2  https://www.rumah.com/listing-properti/dijual-...
# 3  https://www.rumah.com/listing-properti/dijual-...
# 4  https://www.rumah.com/listing-properti/dijual-...
#
#                                             location  bed  bath  area  \
# 0  Jalan camar bintaro sektor 3, Bintaro, Tangera...  3.0   2.0   200
# 1           Ciputat Timur, Tangerang Selatan, Banten  4.0   4.0   200
# 2                 Ciputat, Tangerang Selatan, Banten  4.0   3.0   110
# 3   Pondok Ranji, Bintaro, Tangerang Selatan, Banten  5.0   5.0   232
# 4  1 jl.Jombang  ,Bintaro, Pondok Aren, Tangerang...  7.0   5.0   540
#
#           price
# 0  4.800000e+09
# 1  2.700000e+09
# 2  1.375000e+09
# 3  4.250000e+09
# 4  5.500000e+09

# %%
train_data.describe()
# Out:
#                 bed          bath          area         price
# count  18948.000000  18948.000000  18948.000000  1.894800e+04
# mean       3.739814      2.966382    178.152259  3.278087e+09
# std        1.324113      1.310335    135.614414  2.840672e+09
# min        1.000000      1.000000     22.000000  1.374264e+07
# 25%        3.000000      2.000000     80.000000  1.380000e+09
# 50%        4.000000      3.000000    140.000000  2.458940e+09
# 75%        4.000000      4.000000    234.000000  4.250000e+09
# max       10.000000     10.000000   1000.000000  1.900000e+10

# %% [markdown]
# Data is reasonable now (after removing outliers). We can proceed to feature engineering.

# %%
train_data.to_csv('train_cleaned.csv', index = False)
test_data.to_csv('test_cleaned.csv', index = False)
