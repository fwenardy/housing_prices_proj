# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
housing_data = pd.read_csv('HousingData.csv', encoding = 'unicode_escape')
housing_data.head()
# Out:
#                                        nav-link href  \
# 0  https://www.rumah.com/listing-properti/dijual-...
# 1  https://www.rumah.com/listing-properti/dijual-...
# 2  https://www.rumah.com/listing-properti/dijual-...
# 3  https://www.rumah.com/listing-properti/dijual-...
# 4  https://www.rumah.com/listing-properti/dijual-...
#
#                             listing-location   price  bed  bath  \
# 0  Gading Serpong, Tangerang Selatan, Banten   6,9 M  5.0   5.0
# 1  Gading Serpong, Tangerang Selatan, Banten   4,5 M  3.0   3.0
# 2  Gading Serpong, Tangerang Selatan, Banten  3,95 M  3.0   3.0
# 3  Gading Serpong, Tangerang Selatan, Banten   3,3 M  4.0   3.0
# 4  Gading Serpong, Tangerang Selatan, Banten   3,5 M  3.0   2.0
#
#   listing-floorarea   listing-floorarea 2
# 0            420 m²  Rp 20.720.721 per m²
# 1            190 m²  Rp 12.747.875 per m²
# 2            132 m²  Rp 30.859.375 per m²
# 3            220 m²  Rp 18.333.333 per m²
# 4            180 m²  Rp 27.777.778 per m²

# %% [markdown]
# Preprocessing

# %%
housing_data = housing_data.rename(columns = {'nav-link href':'url', 'listing-location': 'location',
                               'listing-floorarea':'area'})

housing_data = housing_data.drop(columns = 'listing-floorarea 2')
housing_data = housing_data.drop_duplicates()
housing_data.head()
# Out:
#                                                  url  \
# 0  https://www.rumah.com/listing-properti/dijual-...
# 1  https://www.rumah.com/listing-properti/dijual-...
# 2  https://www.rumah.com/listing-properti/dijual-...
# 3  https://www.rumah.com/listing-properti/dijual-...
# 4  https://www.rumah.com/listing-properti/dijual-...
#
#                                     location   price  bed  bath    area
# 0  Gading Serpong, Tangerang Selatan, Banten   6,9 M  5.0   5.0  420 m²
# 1  Gading Serpong, Tangerang Selatan, Banten   4,5 M  3.0   3.0  190 m²
# 2  Gading Serpong, Tangerang Selatan, Banten  3,95 M  3.0   3.0  132 m²
# 3  Gading Serpong, Tangerang Selatan, Banten   3,3 M  4.0   3.0  220 m²
# 4  Gading Serpong, Tangerang Selatan, Banten   3,5 M  3.0   2.0  180 m²

# %% [markdown]
# Splitting into Train and Test sets

# %%
y = housing_data['price'] 
X = housing_data.drop(columns = 'price')

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1, test_size = 0.2)

#combining these split datasets
train_data = X_train
train_data['price'] = y_train

test_data = X_test
test_data['price'] = y_test

# %%
train_data.head()
# Out:
#                                                      url  \
# 20360  https://www.rumah.com/listing-properti/dijual-...
# 21203  https://www.rumah.com/listing-properti/dijual-...
# 26019  https://www.rumah.com/listing-properti/dijual-...
# 6750   https://www.rumah.com/listing-properti/dijual-...
# 16352  https://www.rumah.com/listing-properti/dijual-...
#
#                                                 location  bed  bath    area  \
# 20360  Jalan camar bintaro sektor 3, Bintaro, Tangera...  3.0   2.0  200 m²
# 21203           Ciputat Timur, Tangerang Selatan, Banten  4.0   4.0  200 m²
# 26019                 Ciputat, Tangerang Selatan, Banten  4.0   3.0  110 m²
# 6750    Pondok Ranji, Bintaro, Tangerang Selatan, Banten  5.0   5.0  232 m²
# 16352  1 jl.Jombang  ,Bintaro, Pondok Aren, Tangerang...  7.0   5.0  540 m²
#
#          price
# 20360    4,8 M
# 21203    2,7 M
# 26019  1,375 M
# 6750    4,25 M
# 16352    5,5 M

# %%
test_data.head()
# Out:
#                                                      url  \
# 461    https://www.rumah.com/listing-properti/dijual-...
# 3358   https://www.rumah.com/listing-properti/dijual-...
# 20663  https://www.rumah.com/listing-properti/dijual-...
# 516    https://www.rumah.com/listing-properti/dijual-...
# 27079  https://www.rumah.com/listing-properti/dijual-...
#
#                                                 location  bed  bath    area  \
# 461             Ciputat Timur, Tangerang Selatan, Banten  6.0   4.0  200 m²
# 3358      Graha Raya, Bintaro, Tangerang Selatan, Banten  3.0   3.0  100 m²
# 20663                 Bintaro, Tangerang Selatan, Banten  5.0   5.0  144 m²
# 516    Kucica bintaro sektor 9, Bintaro, Tangerang Se...  4.0   3.0  300 m²
# 27079                 Bintaro, Tangerang Selatan, Banten  5.0   6.0  350 m²
#
#         price
# 461    3,75 M
# 3358    1,3 M
# 20663   4,1 M
# 516     4,9 M
# 27079  3,75 M

# %% [markdown]
# Converting to csv

# %%
train_data.to_csv('train.csv')  
test_data.to_csv('test.csv')
